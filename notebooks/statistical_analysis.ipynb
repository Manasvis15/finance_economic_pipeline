# %%
import sys
sys.path.append('C:/Users/HP/Documents/assessment')  # root folder path

#calling functions
from utils.ingestion import load_csv
#loading data
df = load_csv('data_80.csv')

# %%
from utils.cleaning import drop_duplicates, fill_nulls, drop_columns, rename_columns, fix_dtypes
df=drop_duplicates(df)
df = fill_nulls(df, strategy='mean')

# %%
import utils.stat_anal as sa

# %%
#columns in the file
#df.columns.tolist()

# %%
#df.describe()

# %%
sa.descriptive_statistics(df) #mean,std,skewness

# %%
sa.correlation_analysis(df) #indicators moving together

# %%
df = sa.growth_rates(df) #GDP, profits, spending

# %%
sa.rolling_statistics(df) #long term trends

# %%
sa.volatility_analysis(df) #unstable periods

# %%
sa.zscore_anomaly_detection(df) #unusual macro events

# %%
sa.trend_decomposition(df, col='Close Price') #seasonality in stocks

# %%
sa.hypothesis_testing(df) #pre vs post 2008 crisis

# %%
sa.stationarity_test(df) #differencing in forecasting

# %%
sa.regression_analysis(df) #macro factors affecting prices

# %%
sa.stock_market_analysis(df) #daily returns

# %%
sa.forex_analysis(df) #USD strength vs macro conditions

# %%
sa.commodity_analysis(df) #oil and gold trends
